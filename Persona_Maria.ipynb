# %% [markdown]
# ### Personas
# Maria(Regular)
# Lives in Lund and travels mornings from Linegården station to Malmö C. Leaves home between 08.00-10.00 and travels back between 16.00 - 18.00.
# ID: tnK534JMwwfhvUEycn69HPbhqkt2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import scipy.spatial.distance
trainingData = np.array(pd.read_csv("data/tnK534JMwwfhvUEycn69HPbhqkt2.csv"))
labelData = trainingData[:,4]
labelData = np.transpose(labelData)
trainingTuples = trainingData[:,:4]

#Minute
plt.title("MinuteOfDay")
plt.hist(trainingData[:,2],60)
plt.show()
#Weekday
names=["Sun","Mon","Tue","Wed","Thur","Fri","Sat","what"]
plt.title("Weekday")
x=plt.bar(names,np.bincount(trainingData[:,3],minlength=7),0.3,)
plt.show()
#Activities
names=["Vehicle","Bicycle","Foot","Still","UnK","Tilting","NN","Walk","Run"]
plt.title("Activities")
x=plt.bar(names,np.bincount(trainingData[:,0],minlength=9),0.3,)
plt.show()
#Location
plt.title("Location")
result2=np.true_divide(trainingData[:,1],10000)
plt.hist(result2,100)
plt.show()

# %% [markdown]
# ! ls
